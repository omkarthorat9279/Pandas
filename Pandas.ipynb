# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarthorat9279/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1D  : Series
# 2D  : DataFrames
# 3D  : Panels
# 4D  : 4D Panels

# %%
a1=[2,4,8,3,7,3]

# %%
a1[2]
# Out:
# 8

# %%
s1=pd.Series(a1)
s1
# Out:
# 0    2
# 1    4
# 2    8
# 3    3
# 4    7
# 5    3
# dtype: int64

# %%
s1[2]
# Out:
# 8

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s1.values
# Out:
# array([2, 4, 8, 3, 7, 3])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
a2=("a","abc","name","hello")

# %%
s2=pd.Series(a2)
s2
# Out:
# 0        a
# 1      abc
# 2     name
# 3    hello
# dtype: object

# %%
s2.values
# Out:
# array(['a', 'abc', 'name', 'hello'], dtype=object)

# %%
a3=np.array([3,7,3,5,1,0,6])
s3=pd.Series(a3)
s3
# Out:
# 0    3
# 1    7
# 2    3
# 3    5
# 4    1
# 5    0
# 6    6
# dtype: int64

# %%
a4={'a':9,'c':14,'f':7,'b':22,'j':32}

# %%
s4=pd.Series(a4)
s4
# Out:
# a     9
# c    14
# f     7
# b    22
# j    32
# dtype: int64

# %%
s4.index
# Out:
# Index(['a', 'c', 'f', 'b', 'j'], dtype='object')

# %%
s4.values
# Out:
# array([ 9, 14,  7, 22, 32])

# %%
s1
# Out:
# 0    2
# 1    4
# 2    8
# 3    3
# 4    7
# 5    3
# dtype: int64

# %%
a1
# Out:
# [2, 4, 8, 3, 7, 3]

# %%
a4=pd.Series(a1,index=['Alpha','Bravo','Charlie','Delta','Echo','Foxtrot'])
a4
# Out:
# Alpha      2
# Bravo      4
# Charlie    8
# Delta      3
# Echo       7
# Foxtrot    3
# dtype: int64

# %%
a4['Bravo']
# Out:
# 4

# %%
a4['Echo']
# Out:
# 7

# %%
a4.index
# Out:
# Index(['Alpha', 'Bravo', 'Charlie', 'Delta', 'Echo', 'Foxtrot'], dtype='object')

# %%
a4.values
# Out:
# array([2, 4, 8, 3, 7, 3])

# %%
a4.shape
# Out:
# (6,)

# %%
a4.dtype
# Out:
# dtype('int64')

# %%
a4.ndim
# Out:
# 1

# %%
a4.size
# Out:
# 6

# %%
a4.nbytes
# Out:
# 48

# %%
# Series: 1 column in excel
# DataFrames: multiple columns; spreadsheet; rows and columns
# DataFrames are combination of multiple series

# %%
cars={'brand':['Volvo','Mitsuibishi','McLaren','Ferrari','Mazda','Suzuki','Tesla'],
      'sales':[12,23,45,32,28,9,26],
      'year':[1985,1956,1972,1998,1949,1992,2002]}

# %%
d1=pd.DataFrame(cars)
d1
# Out:
#          brand  sales  year
# 0        Volvo     12  1985
# 1  Mitsuibishi     23  1956
# 2      McLaren     45  1972
# 3      Ferrari     32  1998
# 4        Mazda     28  1949
# 5       Suzuki      9  1992
# 6        Tesla     26  2002

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.size
# Out:
# 21

# %%
d1.shape
# Out:
# (7, 3)

# %%
d1.ndim
# Out:
# 2

# %%
# Task
# create a numpy array of random numbers between 35 and 50 in the shape of (5,6). name the array as marks.
# keep the seed value as 8.
# Create a list of 5 student names. Name the list as students.
# Create a list of 6 subjecct names. Name the list as subjects.

# %%
np.random.seed(8)
marks=np.random.randint(35,50,(5,6))
marks

# %%
students=["Mark","Luke","Jude","Kevin","Drake"]
subjects=["Math","Computers","Sports","Biology","Physics","Language"]

# %%
df=pd.DataFrame(marks,index=students,columns=subjects)
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language
# Mark     38         39      36       44       40        45
# Luke     43         38      43       35       48        40
# Jude     47         36      38       45       46        47
# Kevin    48         44      48       48       37        46
# Drake    37         49      41       48       43        44

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Mark to Drake
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Math       5 non-null      int64
#  1   Computers  5 non-null      int64
#  2   Sports     5 non-null      int64
#  3   Biology    5 non-null      int64
#  4   Physics    5 non-null      int64
#  5   Language   5 non-null      int64
# dtypes: int64(6)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#             Math  Computers     Sports    Biology    Physics   Language
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   42.600000  41.200000  41.200000  44.000000  42.800000  44.400000
# std     5.029911   5.263079   4.658326   5.338539   4.438468   2.701851
# min    37.000000  36.000000  36.000000  35.000000  37.000000  40.000000
# 25%    38.000000  38.000000  38.000000  44.000000  40.000000  44.000000
# 50%    43.000000  39.000000  41.000000  45.000000  43.000000  45.000000
# 75%    47.000000  44.000000  43.000000  48.000000  46.000000  46.000000
# max    48.000000  49.000000  48.000000  48.000000  48.000000  47.000000

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language
# Mark     38         39      36       44       40        45
# Luke     43         38      43       35       48        40
# Jude     47         36      38       45       46        47
# Kevin    48         44      48       48       37        46
# Drake    37         49      41       48       43        44

# %%
df['Language']
# Out:
# Mark     45
# Luke     40
# Jude     47
# Kevin    46
# Drake    44
# Name: Language, dtype: int64

# %%
df['Sports']
# Out:
# Mark     36
# Luke     43
# Jude     38
# Kevin    48
# Drake    41
# Name: Sports, dtype: int64

# %%
df.sum(axis=0)
# Out:
# Math         213
# Computers    206
# Sports       206
# Biology      220
# Physics      214
# Language     222
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# Mark     242
# Luke     247
# Jude     259
# Kevin    271
# Drake    262
# dtype: int64

# %%
df.mean(axis=0)
# Out:
# Math         42.6
# Computers    41.2
# Sports       41.2
# Biology      44.0
# Physics      42.8
# Language     44.4
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# Mark     40.333333
# Luke     41.166667
# Jude     43.166667
# Kevin    45.166667
# Drake    43.666667
# dtype: float64

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language
# Mark     38         39      36       44       40        45
# Luke     43         38      43       35       48        40
# Jude     47         36      38       45       46        47
# Kevin    48         44      48       48       37        46
# Drake    37         49      41       48       43        44

# %%
df['Total']=df.sum(axis=1)

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total
# Mark     38         39      36       44       40        45    242
# Luke     43         38      43       35       48        40    247
# Jude     47         36      38       45       46        47    259
# Kevin    48         44      48       48       37        46    271
# Drake    37         49      41       48       43        44    262

# %%
df['Total_Marks']=df['Math']+df['Computers']+df['Sports']+df['Biology']+df['Physics']+df['Language']

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total  Total_Marks
# Mark     38         39      36       44       40        45    242          242
# Luke     43         38      43       35       48        40    247          247
# Jude     47         36      38       45       46        47    259          259
# Kevin    48         44      48       48       37        46    271          271
# Drake    37         49      41       48       43        44    262          262

# %%
df["Percentage"]=round((df['Total']/300)*100,2)
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total  \
# Mark     38         39      36       44       40        45    242
# Luke     43         38      43       35       48        40    247
# Jude     47         36      38       45       46        47    259
# Kevin    48         44      48       48       37        46    271
# Drake    37         49      41       48       43        44    262
#
#        Total_Marks  Percentage
# Mark           242       80.67
# Luke           247       82.33
# Jude           259       86.33
# Kevin          271       90.33
# Drake          262       87.33

# %%
df.drop(columns=['Total_Marks'])
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total  Percentage
# Mark     38         39      36       44       40        45    242       80.67
# Luke     43         38      43       35       48        40    247       82.33
# Jude     47         36      38       45       46        47    259       86.33
# Kevin    48         44      48       48       37        46    271       90.33
# Drake    37         49      41       48       43        44    262       87.33

# %%
df

# %%
df=df.drop(columns=['Total_Marks'])

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total  Percentage
# Mark     38         39      36       44       40        45    242       80.67
# Luke     43         38      43       35       48        40    247       82.33
# Jude     47         36      38       45       46        47    259       86.33
# Kevin    48         44      48       48       37        46    271       90.33
# Drake    37         49      41       48       43        44    262       87.33

# %%
df.drop(columns=["Percentage"],inplace=True)

# %%
df
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total
# Mark     38         39      36       44       40        45    242
# Luke     43         38      43       35       48        40    247
# Jude     47         36      38       45       46        47    259
# Kevin    48         44      48       48       37        46    271
# Drake    37         49      41       48       43        44    262

# %%
df.drop("Kevin",axis=0)
# Out:
#        Math  Computers  Sports  Biology  Physics  Language  Total
# Mark     38         39      36       44       40        45    242
# Luke     43         38      43       35       48        40    247
# Jude     47         36      38       45       46        47    259
# Drake    37         49      41       48       43        44    262

# %%
df.drop("Math",axis=1)
# Out:
#        Computers  Sports  Biology  Physics  Language  Total
# Mark          39      36       44       40        45    242
# Luke          38      43       35       48        40    247
# Jude          36      38       45       46        47    259
# Kevin         44      48       48       37        46    271
# Drake         49      41       48       43        44    262

# %%
# Missing Values

# %%
d1={'Football':   [5,2,4,7,8,3,2,5],
    'Tennis':     [3,8,1,np.nan,5,7,2,5],
    'Basketball': [np.nan,8,2,np.nan,3,np.nan,8,4],
    'Baseball':   [3,7,3,np.nan,4,7,np.nan,8]}

# %%
d1
# Out:
# {'Football': [5, 2, 4, 7, 8, 3, 2, 5],
#  'Tennis': [3, 8, 1, nan, 5, 7, 2, 5],
#  'Basketball': [nan, 8, 2, nan, 3, nan, 8, 4],
#  'Baseball': [3, 7, 3, nan, 4, 7, nan, 8]}

# %%
sports=pd.DataFrame(d1,index=['Alpha','Bravo','Charlie','Delta','Echo','Foxtrot','Golf','Hotel'])
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         NaN       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     NaN         NaN       NaN
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         NaN       7.0
# Golf            2     2.0         8.0       NaN
# Hotel           5     5.0         4.0       8.0

# %%
# NaN: Not A Number: null value or missing value or corrupted value

# Handling of missing values
# 1. Remove the rows containing the missing values
# 2. Remove the columns containing the missing values
# 3. Fill the missing values with 0 or a constant number
# 4. Fill the missing values with mean or median or mode
# 5. Fill the missing values with some advanced ML techniques

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         NaN       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     NaN         NaN       NaN
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         NaN       7.0
# Golf            2     2.0         8.0       NaN
# Hotel           5     5.0         4.0       8.0

# %%
sports.isnull()
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha       False   False        True     False
# Bravo       False   False       False     False
# Charlie     False   False       False     False
# Delta       False    True        True      True
# Echo        False   False       False     False
# Foxtrot     False   False        True     False
# Golf        False   False       False      True
# Hotel       False   False       False     False

# %%
sports.isnull().sum()
# Out:
# Football      0
# Tennis        1
# Basketball    3
# Baseball      2
# dtype: int64

# %%
sports.isnull().mean()
# Out:
# Football      0.000
# Tennis        0.125
# Basketball    0.375
# Baseball      0.250
# dtype: float64

# %%
sports.isna().sum()
# Out:
# Football      0
# Tennis        1
# Basketball    3
# Baseball      2
# dtype: int64

# %%
sports.dropna(axis=0)
# Out:
#          Football  Tennis  Basketball  Baseball
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Echo            8     5.0         3.0       4.0
# Hotel           5     5.0         4.0       8.0

# %%
sports.dropna(axis=1)
# Out:
#          Football
# Alpha           5
# Bravo           2
# Charlie         4
# Delta           7
# Echo            8
# Foxtrot         3
# Golf            2
# Hotel           5

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         NaN       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     NaN         NaN       NaN
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         NaN       7.0
# Golf            2     2.0         8.0       NaN
# Hotel           5     5.0         4.0       8.0

# %%
sports.fillna(value=0)
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         0.0       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     0.0         0.0       0.0
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         0.0       7.0
# Golf            2     2.0         8.0       0.0
# Hotel           5     5.0         4.0       8.0

# %%
sports.fillna(value=5)
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         5.0       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     5.0         5.0       5.0
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         5.0       7.0
# Golf            2     2.0         8.0       5.0
# Hotel           5     5.0         4.0       8.0

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         NaN       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     NaN         NaN       NaN
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         NaN       7.0
# Golf            2     2.0         8.0       NaN
# Hotel           5     5.0         4.0       8.0

# %%
sports.mean()
# Out:
# Football      4.500000
# Tennis        4.428571
# Basketball    5.000000
# Baseball      5.333333
# dtype: float64

# %%
sports.fillna(value=sports.mean())
# Out:
#          Football    Tennis  Basketball  Baseball
# Alpha           5  3.000000         5.0  3.000000
# Bravo           2  8.000000         8.0  7.000000
# Charlie         4  1.000000         2.0  3.000000
# Delta           7  4.428571         5.0  5.333333
# Echo            8  5.000000         3.0  4.000000
# Foxtrot         3  7.000000         5.0  7.000000
# Golf            2  2.000000         8.0  5.333333
# Hotel           5  5.000000         4.0  8.000000

# %%
sports.fillna(value=sports.median())
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         4.0       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     5.0         4.0       5.5
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         4.0       7.0
# Golf            2     2.0         8.0       5.5
# Hotel           5     5.0         4.0       8.0

# %%
sports.mode()
# Out:
#    Football  Tennis  Basketball  Baseball
# 0         2     5.0         8.0       3.0
# 1         5     NaN         NaN       7.0

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         NaN       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     NaN         NaN       NaN
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         NaN       7.0
# Golf            2     2.0         8.0       NaN
# Hotel           5     5.0         4.0       8.0

# %%
sports['Basketball'].mean()
# Out:
# 5.0

# %%
sports['Basketball']=sports['Basketball'].fillna(value=sports['Basketball'].mean())

# %%
sports['Tennis'].mode()
# Out:
# 0    5.0
# Name: Tennis, dtype: float64

# %%
sports['Tennis'].mode()[0]
# Out:
# 5.0

# %%
sports['Tennis']=sports['Tennis'].fillna(value=sports['Tennis'].mode()[0])

# %%
sports['Baseball']
# Out:
# Alpha      3.0
# Bravo      7.0
# Charlie    3.0
# Delta      NaN
# Echo       4.0
# Foxtrot    7.0
# Golf       NaN
# Hotel      8.0
# Name: Baseball, dtype: float64

# %%
sports['Baseball'].median()
# Out:
# 5.5

# %%
sports['Baseball']=sports['Baseball'].fillna(value=sports['Baseball'].median())

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         5.0       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     5.0         5.0       5.5
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         5.0       7.0
# Golf            2     2.0         8.0       5.5
# Hotel           5     5.0         4.0       8.0

# %%
sports.isnull().sum()
# Out:
# Football      0
# Tennis        0
# Basketball    0
# Baseball      0
# dtype: int64

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Alpha           5     3.0         5.0       3.0
# Bravo           2     8.0         8.0       7.0
# Charlie         4     1.0         2.0       3.0
# Delta           7     5.0         5.0       5.5
# Echo            8     5.0         3.0       4.0
# Foxtrot         3     7.0         5.0       7.0
# Golf            2     2.0         8.0       5.5
# Hotel           5     5.0         4.0       8.0

# %%
sports.reset_index(drop=True,inplace=True)

# %%
sports
# Out:
#    Football  Tennis  Basketball  Baseball
# 0         5     3.0         5.0       3.0
# 1         2     8.0         8.0       7.0
# 2         4     1.0         2.0       3.0
# 3         7     5.0         5.0       5.5
# 4         8     5.0         3.0       4.0
# 5         3     7.0         5.0       7.0
# 6         2     2.0         8.0       5.5
# 7         5     5.0         4.0       8.0

# %%
sports.set_index([['Red','Green','Blue','Magenta','Pink','Lime','Black','White']],inplace=True)

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Red             5     3.0         5.0       3.0
# Green           2     8.0         8.0       7.0
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0
# Lime            3     7.0         5.0       7.0
# Black           2     2.0         8.0       5.5
# White           5     5.0         4.0       8.0

# %%
sports[['Baseball','Tennis','Basketball']]
# Out:
#          Baseball  Tennis  Basketball
# Red           3.0     3.0         5.0
# Green         7.0     8.0         8.0
# Blue          3.0     1.0         2.0
# Magenta       5.5     5.0         5.0
# Pink          4.0     5.0         3.0
# Lime          7.0     7.0         5.0
# Black         5.5     2.0         8.0
# White         8.0     5.0         4.0

# %%
sports.head()
# Out:
#          Football  Tennis  Basketball  Baseball
# Red             5     3.0         5.0       3.0
# Green           2     8.0         8.0       7.0
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0

# %%
sports.head(3)
# Out:
#        Football  Tennis  Basketball  Baseball
# Red           5     3.0         5.0       3.0
# Green         2     8.0         8.0       7.0
# Blue          4     1.0         2.0       3.0

# %%
sports.head(7)
# Out:
#          Football  Tennis  Basketball  Baseball
# Red             5     3.0         5.0       3.0
# Green           2     8.0         8.0       7.0
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0
# Lime            3     7.0         5.0       7.0
# Black           2     2.0         8.0       5.5

# %%
sports.tail()
# Out:
#          Football  Tennis  Basketball  Baseball
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0
# Lime            3     7.0         5.0       7.0
# Black           2     2.0         8.0       5.5
# White           5     5.0         4.0       8.0

# %%
sports.tail(2)
# Out:
#        Football  Tennis  Basketball  Baseball
# Black         2     2.0         8.0       5.5
# White         5     5.0         4.0       8.0

# %%
sports[2:5]
# Out:
#          Football  Tennis  Basketball  Baseball
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0

# %%
sports[:3]
# Out:
#        Football  Tennis  Basketball  Baseball
# Red           5     3.0         5.0       3.0
# Green         2     8.0         8.0       7.0
# Blue          4     1.0         2.0       3.0

# %%
sports[4:]
# Out:
#        Football  Tennis  Basketball  Baseball
# Pink          8     5.0         3.0       4.0
# Lime          3     7.0         5.0       7.0
# Black         2     2.0         8.0       5.5
# White         5     5.0         4.0       8.0

# %%
sports[:]
# Out:
#          Football  Tennis  Basketball  Baseball
# Red             5     3.0         5.0       3.0
# Green           2     8.0         8.0       7.0
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0
# Lime            3     7.0         5.0       7.0
# Black           2     2.0         8.0       5.5
# White           5     5.0         4.0       8.0

# %%
sports.sample()
# Out:
#       Football  Tennis  Basketball  Baseball
# Blue         4     1.0         2.0       3.0

# %%
sports.sample(3)
# Out:
#        Football  Tennis  Basketball  Baseball
# Pink          8     5.0         3.0       4.0
# Black         2     2.0         8.0       5.5
# Lime          3     7.0         5.0       7.0

# %%
sports.sample(3,random_state=13)
# Out:
#          Football  Tennis  Basketball  Baseball
# Green           2     8.0         8.0       7.0
# Pink            8     5.0         3.0       4.0
# Magenta         7     5.0         5.0       5.5

# %%
# row navigations
# df.head(), df.tail(),df[:],df.sample()

# %%
sports
# Out:
#          Football  Tennis  Basketball  Baseball
# Red             5     3.0         5.0       3.0
# Green           2     8.0         8.0       7.0
# Blue            4     1.0         2.0       3.0
# Magenta         7     5.0         5.0       5.5
# Pink            8     5.0         3.0       4.0
# Lime            3     7.0         5.0       7.0
# Black           2     2.0         8.0       5.5
# White           5     5.0         4.0       8.0

# %%
sports.iloc[3:7,2:4]
# Out:
#          Basketball  Baseball
# Magenta         5.0       5.5
# Pink            3.0       4.0
# Lime            5.0       7.0
# Black           8.0       5.5

# %%
sports.iloc[2:5,1:3]
# Out:
#          Tennis  Basketball
# Blue        1.0         2.0
# Magenta     5.0         5.0
# Pink        5.0         3.0

# %%
sports.iloc[[2,3,4],1:3]
# Out:
#          Tennis  Basketball
# Blue        1.0         2.0
# Magenta     5.0         5.0
# Pink        5.0         3.0

# %%
sports.iloc[[2,3,4],[1,2]]
# Out:
#          Tennis  Basketball
# Blue        1.0         2.0
# Magenta     5.0         5.0
# Pink        5.0         3.0

# %%
sports.iloc[[5,2,7,2,3],[2,1,3]]
# Out:
#          Basketball  Tennis  Baseball
# Lime            5.0     7.0       7.0
# Blue            2.0     1.0       3.0
# White           4.0     5.0       8.0
# Blue            2.0     1.0       3.0
# Magenta         5.0     5.0       5.5

# %%
sports.loc[["Lime","Blue",'Black',"Red"],["Tennis","Football"]]
# Out:
#        Tennis  Football
# Lime      7.0         3
# Blue      1.0         4
# Black     2.0         2
# Red       3.0         5

# %%
d={'id':np.array([1,2,3,4,5]),'Employee':np.array(['Mr X','Mr Y','Mr Z','Mr A','Mr B'])}
a1=pd.DataFrame(d)
a1
# Out:
#    id Employee
# 0   1     Mr X
# 1   2     Mr Y
# 2   3     Mr Z
# 3   4     Mr A
# 4   5     Mr B

# %%
d={'id':np.array([7,2,6,4,5]),'Designation':['Analyst','Sr. Analyst','Associate','Director','Head of Ops']}
a2=pd.DataFrame(d)
a2
# Out:
#    id  Designation
# 0   7      Analyst
# 1   2  Sr. Analyst
# 2   6    Associate
# 3   4     Director
# 4   5  Head of Ops

# %%
# Joins/Merges
# inner
# outer
# left
# right

# %%
pd.merge(a1,a2)
# Out:
#    id Employee  Designation
# 0   2     Mr Y  Sr. Analyst
# 1   4     Mr A     Director
# 2   5     Mr B  Head of Ops

# %%
pd.merge(a1,a2,how="inner",on='id')
# Out:
#    id Employee  Designation
# 0   2     Mr Y  Sr. Analyst
# 1   4     Mr A     Director
# 2   5     Mr B  Head of Ops

# %%
pd.merge(a1,a2,how="left",on='id')
# Out:
#    id Employee  Designation
# 0   1     Mr X          NaN
# 1   2     Mr Y  Sr. Analyst
# 2   3     Mr Z          NaN
# 3   4     Mr A     Director
# 4   5     Mr B  Head of Ops

# %%
pd.merge(a1,a2,how="right",on='id')
# Out:
#    id Employee  Designation
# 0   7      NaN      Analyst
# 1   2     Mr Y  Sr. Analyst
# 2   6      NaN    Associate
# 3   4     Mr A     Director
# 4   5     Mr B  Head of Ops

# %%
pd.merge(a1,a2,how="outer",on='id')
# Out:
#    id Employee  Designation
# 0   1     Mr X          NaN
# 1   2     Mr Y  Sr. Analyst
# 2   3     Mr Z          NaN
# 3   4     Mr A     Director
# 4   5     Mr B  Head of Ops
# 5   7      NaN      Analyst
# 6   6      NaN    Associate

# %%
d={'emp_id':np.array([1,2,3,4,5]),'Employee':np.array(['Mr X','Mr Y','Mr Z','Mr A','Mr B'])}
a3=pd.DataFrame(d)
a3
# Out:
#    emp_id Employee
# 0       1     Mr X
# 1       2     Mr Y
# 2       3     Mr Z
# 3       4     Mr A
# 4       5     Mr B

# %%
a2
# Out:
#    id  Designation
# 0   7      Analyst
# 1   2  Sr. Analyst
# 2   6    Associate
# 3   4     Director
# 4   5  Head of Ops

# %%
pd.merge(a3,a2,left_on="emp_id", right_on="id",how="inner")
# Out:
#    emp_id Employee  id  Designation
# 0       2     Mr Y   2  Sr. Analyst
# 1       4     Mr A   4     Director
# 2       5     Mr B   5  Head of Ops

# %%
d1={'Name':np.array(['Mr A','Mr B','Mr C']),'Height':np.array([145,167,156])}
d2={'Name':np.array(['Mr X','Mr Y','Mr Z']),'Height':np.array([154,178,164])}

# %%
df1=pd.DataFrame(d1)
df2=pd.DataFrame(d2)

# %%
df1
# Out:
#    Name  Height
# 0  Mr A     145
# 1  Mr B     167
# 2  Mr C     156

# %%
df2
# Out:
#    Name  Height
# 0  Mr X     154
# 1  Mr Y     178
# 2  Mr Z     164

# %%
pd.concat([df1,df2])
# Out:
#    Name  Height
# 0  Mr A     145
# 1  Mr B     167
# 2  Mr C     156
# 0  Mr X     154
# 1  Mr Y     178
# 2  Mr Z     164

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#    Name  Height
# 0  Mr A     145
# 1  Mr B     167
# 2  Mr C     156
# 3  Mr X     154
# 4  Mr Y     178
# 5  Mr Z     164

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    Name  Height  Name  Height
# 0  Mr A     145  Mr X     154
# 1  Mr B     167  Mr Y     178
# 2  Mr C     156  Mr Z     164

# %%
d3={'Name':np.array(['Mr X','Mr Y','Mr Z']),'Weight':np.array([154,178,164])}

# %%
df3=pd.DataFrame(d3)

# %%
pd.concat([df1,df3])
# Out:
#    Name  Height  Weight
# 0  Mr A   145.0     NaN
# 1  Mr B   167.0     NaN
# 2  Mr C   156.0     NaN
# 0  Mr X     NaN   154.0
# 1  Mr Y     NaN   178.0
# 2  Mr Z     NaN   164.0

# %%
pd.concat([df1,df3],ignore_index=True)
# Out:
#    Name  Height  Weight
# 0  Mr A   145.0     NaN
# 1  Mr B   167.0     NaN
# 2  Mr C   156.0     NaN
# 3  Mr X     NaN   154.0
# 4  Mr Y     NaN   178.0
# 5  Mr Z     NaN   164.0

# %%
df2.append(df1,ignore_index=True)
# Out:
# <ipython-input-29-223b0249ef4c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append(df1,ignore_index=True)
#    Name  Height
# 0  Mr X     154
# 1  Mr Y     178
# 2  Mr Z     164
# 3  Mr A     145
# 4  Mr B     167
# 5  Mr C     156

# %%
# pd.DataFrame()
# pd.read_csv()
# pd.read_excel()
# pd.read_html()
# pd.read_sql()
# pd.read_json()
# pd.read_table()

# %%
df=pd.read_csv("/content/drive/MyDrive/KnowlegeHut UpGrad/KH_BootCamp 2023 06/Datasets/CarPrice_Assignment.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 5330

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/KnowlegeHut UpGrad/KH_BootCamp 2023 06/Datasets/Cars.csv")
df
# Out:
#                                                       Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# Chevrolet Chevelle Malibu;18 0;8;307 0;130 0;3504;12                                             0;70;US
# Buick Skylark 320;15         0;8;350 0;165 0;3693;11                                             5;70;US
# Plymouth Satellite;18        0;8;318 0;150 0;3436;11                                             0;70;US
# AMC Rebel SST;16             0;8;304 0;150 0;3433;12                                             0;70;US
# Ford Torino;17               0;8;302 0;140 0;3449;10                                             5;70;US
# ...                                                                                                  ...
# Ford Mustang GL;27           0;4;140 0;86  00;2790;15                                            6;82;US
# Volkswagen Pickup;44         0;4;97  00;52 00;2130;24                                        6;82;Europe
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/KnowlegeHut UpGrad/KH_BootCamp 2023 06/Datasets/Cars.csv",sep=";")
df
# Out:
#                            Car   MPG  Cylinders Displacement Horsepower  \
# 0    Chevrolet Chevelle Malibu  18,0          8        307,0      130,0
# 1            Buick Skylark 320  15,0          8        350,0      165,0
# 2           Plymouth Satellite  18,0          8        318,0      150,0
# 3                AMC Rebel SST  16,0          8        304,0      150,0
# 4                  Ford Torino  17,0          8        302,0      140,0
# ..                         ...   ...        ...          ...        ...
# 401            Ford Mustang GL  27,0          4        140,0      86,00
# 402          Volkswagen Pickup  44,0          4        97,00      52,00
# 403              Dodge Rampage  32,0          4        135,0      84,00
# 404                Ford Ranger  28,0          4        120,0      79,00
# 405                 Chevy S-10  31,0          4        119,0      82,00
#
#      Weight Acceleration  Model  Origin
# 0      3504         12,0     70      US
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    object
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    object
#  4   Horsepower    406 non-null    object
#  5   Weight        406 non-null    int64
#  6   Acceleration  406 non-null    object
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 28.7+ KB

# %%
df.nunique()
# Out:
# Car             308
# MPG             130
# Cylinders         5
# Displacement     83
# Horsepower       94
# Weight          356
# Acceleration     97
# Model            13
# Origin            3
# dtype: int64

# %%
df['Origin'].unique()
# Out:
# array(['US', 'Europe', 'Japan'], dtype=object)

# %%
np.unique(df['Origin'])
# Out:
# array(['Europe', 'Japan', 'US'], dtype=object)

# %%
np.unique(df['Origin'],return_counts=True)
# Out:
# (array(['Europe', 'Japan', 'US'], dtype=object), array([ 73,  79, 254]))

# %%
df['Origin'].value_counts()
# Out:
# US        254
# Japan      79
# Europe     73
# Name: Origin, dtype: int64

# %%
origin=df['Origin'].value_counts()
origin
# Out:
# US        254
# Japan      79
# Europe     73
# Name: Origin, dtype: int64

# %%
origin.index
# Out:
# Index(['US', 'Japan', 'Europe'], dtype='object')

# %%
origin.values
# Out:
# array([254,  79,  73])

# %%
plt.bar(origin.index,origin.values)
plt.show()

# %%
df['Origin'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.sample(3)
# Out:
#               Car   MPG  Cylinders Displacement Horsepower  Weight  \
# 283    Saab 99gle  21,6          4        121,0      115,0    2795
# 235  Ford Grenada  18,5          6        250,0      98,00    3525
# 389  Honda Accord  36,0          4        107,0      75,00    2205
#
#     Acceleration  Model  Origin
# 283         15,7     78  Europe
# 235         19,0     77      US
# 389         14,5     82   Japan

# %%
a="21,6"

# %%
a=a.replace(",",".")
float(a)
# Out:
# 21.6

# %%
(lambda a:a.replace(",","."))("18,5")
# Out:
# '18.5'

# %%
df['MPG']
# Out:
# 0      18,0
# 1      15,0
# 2      18,0
# 3      16,0
# 4      17,0
#        ...
# 401    27,0
# 402    44,0
# 403    32,0
# 404    28,0
# 405    31,0
# Name: MPG, Length: 406, dtype: object

# %%
df['MPG'].apply(lambda a:a.replace(",","."))
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 401    27.0
# 402    44.0
# 403    32.0
# 404    28.0
# 405    31.0
# Name: MPG, Length: 406, dtype: object

# %%
df['MPG'].apply(lambda a:a.replace(",",".")).astype('float')
# df['MPG'].apply(lambda a:float(a.replace(",",".")))     #Alternate method
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 401    27.0
# 402    44.0
# 403    32.0
# 404    28.0
# 405    31.0
# Name: MPG, Length: 406, dtype: float64

# %%
df['MPG']=df['MPG'].apply(lambda a:a.replace(",",".")).astype('float')

# %%
df['MPG']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 401    27.0
# 402    44.0
# 403    32.0
# 404    28.0
# 405    31.0
# Name: MPG, Length: 406, dtype: float64

# %%
df
# Out:
#                            Car   MPG  Cylinders Displacement Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8        307,0      130,0
# 1            Buick Skylark 320  15.0          8        350,0      165,0
# 2           Plymouth Satellite  18.0          8        318,0      150,0
# 3                AMC Rebel SST  16.0          8        304,0      150,0
# 4                  Ford Torino  17.0          8        302,0      140,0
# ..                         ...   ...        ...          ...        ...
# 401            Ford Mustang GL  27.0          4        140,0      86,00
# 402          Volkswagen Pickup  44.0          4        97,00      52,00
# 403              Dodge Rampage  32.0          4        135,0      84,00
# 404                Ford Ranger  28.0          4        120,0      79,00
# 405                 Chevy S-10  31.0          4        119,0      82,00
#
#      Weight Acceleration  Model  Origin
# 0      3504         12,0     70      US
# ...

# %%
# Changing the columns from string to float after replacing comma with a decimal point
df['Displacement']=df['Displacement'].apply(lambda a:a.replace(",",".")).astype('float')
df['Horsepower']=df['Horsepower'].apply(lambda a:a.replace(",",".")).astype('float')
df['Acceleration']=df['Acceleration'].apply(lambda a:a.replace(",",".")).astype('float')

# %%
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1            Buick Skylark 320  15.0          8         350.0       165.0
# 2           Plymouth Satellite  18.0          8         318.0       150.0
# 3                AMC Rebel SST  16.0          8         304.0       150.0
# 4                  Ford Torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0          4         140.0        86.0
# 402          Volkswagen Pickup  44.0          4          97.0        52.0
# 403              Dodge Rampage  32.0          4         135.0        84.0
# 404                Ford Ranger  28.0          4         120.0        79.0
# 405                 Chevy S-10  31.0          4         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    int64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.7+ KB
